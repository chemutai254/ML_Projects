# %% [markdown]
# ### PANDAS - Python Data Analysis Library
# - Provides fast, flexible, and expressive data sctructures designed to make working with "relational" or "labeled" data both easy and intuitive
# - High-level building block for doing practical, real-world data analysis in Python.
# - Goal: It is the most powerful open source data analysis/manipulation tool available in any language.
# - Series - 1 Dimension
# - DataFrame - 2 Dimension

# %% [markdown]
# #### Creating a series
# - Use a list
# - Use a dictionary
# - Using a Numpy Array

# %%
# Import pandas
import pandas as pd

# %%
# Create a series using a list - pd.Series(data=data, index=label)
age = [12, 14,44, 23, 45, 56, 87, 44]
age
type(age)
# Out:
# list

# %%
customer = pd.Series(data=age)
customer
# Out:
# 0    12
# 1    14
# 2    44
# 3    23
# 4    45
# 5    56
# 6    87
# 7    44
# dtype: int64

# %%
name = ['Nancy', 'Ann', 'Ken', 'Mary', 'Elizabeth', 'Allan', 'Mercy', 'Pauline']
customer = pd.Series(data=age, index=name)
customer
# Out:
# Nancy        12
# Ann          14
# Ken          44
# Mary         23
# Elizabeth    45
# Allan        56
# Mercy        87
# Pauline      44
# dtype: int64

# %%
# Creating a Series using a Dictionary - pd.Series(dictionary)
movies = {'Avatar':2022, 'Black Panther':2020, 'Saw':2000, 'Money Heist':2019, 'Avenger':2020, 'Iron Man':2021, 'Hulk':2000}
movies
# Out:
# {'Avatar': 2022,
#  'Black Panther': 2020,
#  'Saw': 2000,
#  'Money Heist': 2019,
#  'Avenger': 2020,
#  'Iron Man': 2021,
#  'Hulk': 2000}

# %%
film = pd.Series(movies)
film
# Out:
# Avatar           2022
# Black Panther    2020
# Saw              2000
# Money Heist      2019
# Avenger          2020
# Iron Man         2021
# Hulk             2000
# dtype: int64

# %%
film.index
# Out:
# Index(['Avatar', 'Black Panther', 'Saw', 'Money Heist', 'Avenger', 'Iron Man',
#        'Hulk'],
#       dtype='object')

# %%
film.values
# Out:
# array([2022, 2020, 2000, 2019, 2020, 2021, 2000], dtype=int64)

# %%
# Movies that were released after 2010
film[film >= 2010]
# Out:
# Avatar           2022
# Black Panther    2020
# Money Heist      2019
# Avenger          2020
# Iron Man         2021
# dtype: int64

# %%
# Movies that were released before 2010
film[film <= 2010]
# Out:
# Saw     2000
# Hulk    2000
# dtype: int64

# %%
# The year Irom Man was made
film['Iron Man']
# Out:
# 2021

# %%
film['Avatar']
# Out:
# 2022

# %%
customer
# Out:
# Nancy        12
# Ann          14
# Ken          44
# Mary         23
# Elizabeth    45
# Allan        56
# Mercy        87
# Pauline      44
# dtype: int64

# %%
customer[customer >= 30]
# Out:
# Ken          44
# Elizabeth    45
# Allan        56
# Mercy        87
# Pauline      44
# dtype: int64

# %%
customer[customer < 40]
# Out:
# Nancy    12
# Ann      14
# Mary     23
# dtype: int64

# %% [markdown]
# #### DataFrame

# %%
# Create a DataFrame using a List
# Customer Revenue
header = ['Name', 'Age', 'Product', 'Quantity', 'Revenue']
df = [['Nancy', 30, 'Car',300, 3000], ['Pauline', 40, 'Book',10, 4500], ['Kerry', 23, 'Bicycle', 80, 3600], ['Perry', 34, 'Table', 50, 2000],['June', 20, 'Chair', 25, 1500]]

# %%
# pd.DataFrame(data=???, Index=???, columns=???)
cust_rev = pd.DataFrame(data=df, columns=header)
cust_rev
# Out:
#       Name  Age  Product  Quantity  Revenue
# 0    Nancy   30      Car       300     3000
# 1  Pauline   40     Book        10     4500
# 2    Kerry   23  Bicycle        80     3600
# 3    Perry   34    Table        50     2000
# 4     June   20    Chair        25     1500

# %%
# Indexing and Filtering
# Age > 25
cust_rev[cust_rev['Age']  > 25]
# Out:
#       Name  Age Product  Quantity  Revenue
# 0    Nancy   30     Car       300     3000
# 1  Pauline   40    Book        10     4500
# 3    Perry   34   Table        50     2000

# %%
# Revenue < 3000
cust_rev[cust_rev['Revenue'] < 3000]
# Out:
#     Name  Age Product  Quantity  Revenue
# 3  Perry   34   Table        50     2000
# 4   June   20   Chair        25     1500

# %%
# See name and revenue only
cust_rev[['Name', 'Revenue']][cust_rev['Revenue'] < 3000]
# Out:
#     Name  Revenue
# 3  Perry     2000
# 4   June     1500

# %%
# Create new column - Revenue/Quantity
cust_rev['Rev/Qty'] = round(cust_rev['Revenue']/cust_rev['Quantity'], 2)
cust_rev
# Out:
#       Name  Age  Product  Quantity  Revenue  Rev/Qty
# 0    Nancy   30      Car       300     3000     10.0
# 1  Pauline   40     Book        10     4500    450.0
# 2    Kerry   23  Bicycle        80     3600     45.0
# 3    Perry   34    Table        50     2000     40.0
# 4     June   20    Chair        25     1500     60.0

# %%
cust_rev[['Name', 'Age', 'Revenue']][cust_rev['Quantity'] > 100]
# Out:
#     Name  Age  Revenue
# 0  Nancy   30     3000

# %% [markdown]
# ### Data Visualization
# #### Matplotlib
# - Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python

# %%
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(data=df, columns=header)
df
# Out:
#       Name  Age  Product  Quantity  Revenue
# 0    Nancy   30      Car       300     3000
# 1  Pauline   40     Book        10     4500
# 2    Kerry   23  Bicycle        80     3600
# 3    Perry   34    Table        50     2000
# 4     June   20    Chair        25     1500

# %%
# plt.plot(X, Y) - Name, Age (Line Chart)
plt.title("Customer Age")
plt.plot(df['Name'], df['Age'])
plt.show() # takes the message below away

# %%
df.sort_values('Quantity', inplace=True, ascending=True) # Inplace affects the dataset

# %%
# Column Chart
plt.title("Total Quantity by Customer")
plt.bar(df['Name'], df['Quantity'])
plt.show() # takes the message below away

# %%
df.sort_values('Quantity', inplace=True, ascending=False) # Inplace affects the dataset

# %%
# Column Chart
plt.title("Total Quantity by Customer")
plt.bar(df['Name'], df['Quantity'])
plt.show() # takes the message below away

# %%
# Bar Chart
plt.title("Total Revenue by Customer")
df.sort_values('Revenue', inplace=True, ascending=False)
plt.barh(df['Name'], df['Revenue'])
plt.show()

# %%
# Scatter Plot - Age and Revenue
plt.title("Relationship between customer Age and Revenue")
plt.scatter(x='Age', y='Revenue', data=df)
plt.show()

# %% [markdown]
# ### Subplots()
# - Used in plotting more than 1 Dimension.

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 10))
axs[0, 0].set_title('Customer Age Analysis')
axs[0, 0].bar(df['Name'], df['Age'], color='r')

axs[0, 1].set_title('Total Quantity by Customer')
axs[0, 1].barh(df['Name'], df['Quantity'], color='b')

axs[1, 0].set_title('Total Revenue by Customer')
axs[1, 0].plot(df['Name'], df['Revenue'], color='g')

axs[1, 1].set_title('Relationship between Age and Revenue')
axs[1, 1].scatter(x='Age', y='Revenue', data=df)

plt.show()

# %% [markdown]
# ### Seaborn
# Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
# - Distribution Plot
# - Categorical Plot
# - Regression Plot

# %% [markdown]
# #### Distribution Plot
# - Distplot
# - Jointplot
# - Pairplot

# %%
import seaborn as sns

# To ignore warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# For learning purposes - It has in-built datasets
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Distplot
sns.distplot(df['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(df['total_bill'], kde=False) # kde - Kernel density estimation
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.distplot(df['total_bill'], kde=False, bins=10)
# Out:
# <Axes: xlabel='total_bill'>

# %%
# Joint Plot - Scatter, Reg, Resid, kde, hex (Analysis of two things)
sns.jointplot(x='total_bill', y='tip', data=df, kind='scatter')

# %%
sns.jointplot(x='total_bill', y='tip', data=df, kind='hex')

# %%
sns.jointplot(x='total_bill', y='tip', data=df, kind='reg')

# %%
sns.jointplot(x='total_bill', y='tip', data=df, kind='kde')

# %%
# Pairplot - Plots all the relationship available in the data
sns.pairplot(df)

# %% [markdown]
# ### Categorical Plot
# - factorplot
# - boxplot
# - barplot
# - countplot
# - violnplot
# - swarmplot
# - stripplot

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# factorplot - Its the generic visualization - factorplot has been depreciated instead use catplot
sns.catplot(x='sex', y='total_bill', data=df, kind='bar')

# %%
# Countplot - Based on a count
sns.countplot(x='sex', data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='day', data=df)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
# Barplot
sns.barplot(x='sex', y='total_bill', data=df)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x='day', y='total_bill', data=df, hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# Boxplot
sns.boxplot(x='sex', y='tip', data=df)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.boxplot(x='sex', y='total_bill', data=df, palette='coolwarm')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
# Regression Plot - lmplot
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot(x='total_bill', y='tip', data=df, hue='sex')
